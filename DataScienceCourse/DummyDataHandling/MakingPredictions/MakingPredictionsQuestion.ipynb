# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
try:
    raw_data = pd.read_csv('1.03. Dummies.csv')
    raw_data.head()
except FileNotFoundError:
    print("File not present")

# %%
raw_data.head(10)
# Out:
#     SAT   GPA Attendance
# 0  1714  2.40         No
# 1  1664  2.52         No
# 2  1760  2.54         No
# 3  1685  2.74         No
# 4  1693  2.83         No
# 5  1670  2.91         No
# 6  1764  3.00         No
# 7  1764  3.00         No
# 8  1792  3.01         No
# 9  1850  3.01         No

# %%
data = raw_data.copy()

# %%
data.head()
# Out:
#     SAT   GPA Attendance
# 0  1714  2.40         No
# 1  1664  2.52         No
# 2  1760  2.54         No
# 3  1685  2.74         No
# 4  1693  2.83         No

# %%
data['Attendance'] = raw_data['Attendance'].map({'Yes':1,'No':0})

# %%
data.head(20)
# Out:
#      SAT   GPA  Attendance
# 0   1714  2.40           0
# 1   1664  2.52           0
# 2   1760  2.54           0
# 3   1685  2.74           0
# 4   1693  2.83           0
# 5   1670  2.91           0
# 6   1764  3.00           0
# 7   1764  3.00           0
# 8   1792  3.01           0
# 9   1850  3.01           0
# 10  1735  3.02           0
# 11  1775  3.07           0
# 12  1735  3.08           0
# 13  1712  3.08           0
# 14  1773  3.12           0
# 15  1872  3.17           1
# 16  1755  3.17           0
# 17  1674  3.17           1
# 18  1842  3.17           0
# 19  1786  3.19           1

# %%
y = data['GPA']
x1 = data[['SAT','Attendance']]

# %%
x = sm.add_constant(x1)
result = sm.OLS(y,x).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    GPA   R-squared:                       0.565
# Model:                            OLS   Adj. R-squared:                  0.555
# Method:                 Least Squares   F-statistic:                     52.70
# Date:                Mon, 10 Jun 2019   Prob (F-statistic):           2.19e-15
# Time:                        22:41:48   Log-Likelihood:                 25.798
# No. Observations:                  84   AIC:                            -45.60
# Df Residuals:                      81   BIC:                            -38.30
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6439      0.358      1.797      0.076      -0.069       1.357
# ...

# %%
plt.scatter(data['SAT'],y)
yhat_no = 0.6439 + 0.0014*data['SAT']
yhat_yes = 0.8665 + 0.0014*data['SAT']
fig = plt.plot(data['SAT'],yhat_no, lw=2, c='#006837')
fig = plt.plot(data['SAT'],yhat_yes, lw=2, c='#a50026')
plt.xlabel('SAT', fontsize = 20)
plt.ylabel('GPA', fontsize = 20)
plt.show()

# %%
plt.scatter(data['SAT'],y,c=data['Attendance'],cmap='RdYlGn_r')
yhat_no = 0.6439 + 0.0014*data['SAT']
yhat_yes = 0.8665 + 0.0014*data['SAT']
fig = plt.plot(data['SAT'],yhat_no, lw=2, c='#006837')
fig = plt.plot(data['SAT'],yhat_yes, lw=2, c='#a50026')
plt.xlabel('SAT', fontsize = 20)
plt.ylabel('GPA', fontsize = 20)
plt.show()

# %%
plt.scatter(data['SAT'],data['GPA'], c=data['Attendance'],cmap='RdYlGn_r')
yhat_no = 0.6439 + 0.0014*data['SAT']
yhat_yes = 0.8665 + 0.0014*data['SAT']
yhat = 0.0017*data['SAT'] + 0.275
fig = plt.plot(data['SAT'],yhat_no, lw=2, c='#006837', label ='regression line1')
fig = plt.plot(data['SAT'],yhat_yes, lw=2, c='#a50026', label ='regression line2')
fig = plt.plot(data['SAT'],yhat, lw=3, c='#4C72B0', label ='regression line')
plt.xlabel('SAT', fontsize = 20)
plt.ylabel('GPA', fontsize = 20)
plt.show()

# %%
x
# Out:
#     const   SAT  Attendance
# 0     1.0  1714           0
# 1     1.0  1664           0
# 2     1.0  1760           0
# 3     1.0  1685           0
# 4     1.0  1693           0
# 5     1.0  1670           0
# 6     1.0  1764           0
# 7     1.0  1764           0
# 8     1.0  1792           0
# 9     1.0  1850           0
# 10    1.0  1735           0
# 11    1.0  1775           0
# 12    1.0  1735           0
# 13    1.0  1712           0
# 14    1.0  1773           0
# 15    1.0  1872           1
# 16    1.0  1755           0
# 17    1.0  1674           1
# 18    1.0  1842           0
# 19    1.0  1786           1
# 20    1.0  1761           0
# 21    1.0  1722           0
# 22    1.0  1663           0
# 23    1.0  1687           0
# 24    1.0  1974           0
# 25    1.0  1826           0
# 26    1.0  1787           0
# 27    1.0  1821           0
# 28    1.0  2020           0
# 29    1.0  1794           0
# ..    ...   ...         ...
# 54    1.0  1879           1
# ...

# %%
new_data = pd.DataFrame({'const':1,'SAT':[1700,1670],'Attendance':[0,1]})

# %%
new_data = new_data[['const','SAT','Attendance']]
new_data
# Out:
#    const   SAT  Attendance
# 0      1  1700           0
# 1      1  1670           1

# %%
new_data.rename(index={0: 'Bob',1:'Alice'})
# Out:
#        const   SAT  Attendance
# Bob        1  1700           0
# Alice      1  1670           1

# %%
predictions = result.predict(new_data)
predictions
# Out:
# 0    3.023513
# 1    3.204163
# dtype: float64

# %%
predictionsdf = pd.DataFrame({'Predictions': predictions})

# %%
predictionsdf
# Out:
#    Predictions
# 0     3.023513
# 1     3.204163

# %%
joinedData = new_data.join(predictionsdf,'inner')

# %%
joinedData
# Out:
#    const   SAT  Attendance  Predictions
# 0      1  1700           0     3.023513
# 1      1  1670           1     3.204163

# %%
joinedData2 = new_data.append(predictionsdf)
joinedData2
# Out:
#    Attendance  Predictions     SAT  const
# 0         0.0          NaN  1700.0    1.0
# 1         1.0          NaN  1670.0    1.0
# 0         NaN     3.023513     NaN    NaN
# 1         NaN     3.204163     NaN    NaN

# %%
joinedData3 = new_data.join(predictionsdf,how='inner')

# %%
joinedData3
# Out:
#    const   SAT  Attendance  Predictions
# 0      1  1700           0     3.023513
# 1      1  1670           1     3.204163

# %%
joinedData3.rename(index={0:'Bob',1:'Alice'})
# Out:
#        const   SAT  Attendance  Predictions
# Bob        1  1700           0     3.023513
# Alice      1  1670           1     3.204163
